# %%
# %sql
CREATE DATABASE avd_db

# %%
# %sql
CREATE DATABASE IF NOT EXISTS avd_db

# %%
# %sql 
DROP DATABASE IF EXISTS avd_db

# %%
# %sql
use avd_db

# %%
# %sql
CREATE TABLE emp(
  id int,
  name VARCHAR(50),
  address VARCHAR(100)
)

# %%
# %sql
DROP TABLE IF EXISTS `avd_db.emp`

# %% [markdown]
# ## Dataframe to Table

# %%
# Create sample data as a Python list of tuples
# Each tuple contains: (language_name, count_value)
data = [
    ("python", 100),
    ("java", 200),
    ("scala", 300)
]

# Convert the Python list into a Spark DataFrame
# Specify column names: "language" and "count"
df = spark.createDataFrame(data, ["language", "count"])

# Display the DataFrame content in a tabular format
df.show()

# Save the DataFrame as a managed table inside a database
# This will create a table named 'course' inside the 'avd_db' database
# Since it's a managed table, Databricks will manage both data + metadata
df.write.saveAsTable("avd_db.course")
# Out:
# +--------+-----+
# |language|count|
# +--------+-----+
# |  python|  100|
# |    java|  200|
# |   scala|  300|
# +--------+-----+

# %%
# %sql
SELECT * FROM avd_db.course
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>language</th><th>count</th></tr></thead><tbody><tr><td>python</td><td>100</td></tr><tr><td>java</td><td>200</td></tr><tr><td>scala</td><td>300</td></tr></tbody></table></div>

# %%
spark.sql("select * from avd_db.course").show()
# Out:
# +--------+-----+
# |language|count|
# +--------+-----+
# |  python|  100|
# |    java|  200|
# |   scala|  300|
# +--------+-----+

# %%
# %sql
desc avd_db.emp
describe detail avd_db.emp 
describe extended avd_db.emp
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>col_name</th><th>data_type</th><th>comment</th></tr></thead><tbody><tr><td>id</td><td>int</td><td>null</td></tr><tr><td>name</td><td>varchar(50)</td><td>null</td></tr><tr><td>address</td><td>varchar(100)</td><td>null</td></tr></tbody></table></div>

# %%
# %sql
describe detail avd_db.emp
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>format</th><th>id</th><th>name</th><th>description</th><th>location</th><th>createdAt</th><th>lastModified</th><th>partitionColumns</th><th>clusteringColumns</th><th>numFiles</th><th>sizeInBytes</th><th>properties</th><th>minReaderVersion</th><th>minWriterVersion</th><th>tableFeatures</th><th>statistics</th><th>clusterByAuto</th></tr></thead><tbody><tr><td>delta</td><td>a15a1210-0119-412a-a9a1-f824450ca08f</td><td>avd_workspace1.avd_db.emp</td><td>null</td><td>abfss://unity-catalog-storage@dbstoragevissqnsxh7qno.dfs.core.windows.net/2337203842480748/__unitystorage/catalogs/4f23fad5-6e40-453f-b6b4-da1ac6b5ab2f/tables/b009f6a3-113d-4f7f-8ad8-215e912582c0</td><td>2025-11-28T17:59:48.182Z</td><td>2025-11-28T17:59:49Z</td><td>List()</td><td>List()</td><td>0</td><td>0</td><td>Map(delta.parquet.compression.codec -> zstd, delta.enableDeletionVectors -> true)</td><td>3</td><td>7</td><td>List(appendOnly, deletionVectors, invariants)</td><td>Map(numRowsDeletedByDeletionVectors -> 0, numDeletionVectors -> 0)</td><td>false</td></tr></tbody></table></div>

# %%
# %sql

describe extended avd_db.emp
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>col_name</th><th>data_type</th><th>comment</th></tr></thead><tbody><tr><td>id</td><td>int</td><td>null</td></tr><tr><td>name</td><td>varchar(50)</td><td>null</td></tr><tr><td>address</td><td>varchar(100)</td><td>null</td></tr><tr><td></td><td></td><td></td></tr><tr><td># Detailed Table Information</td><td></td><td></td></tr><tr><td>Catalog</td><td>avd_workspace1</td><td></td></tr><tr><td>Database</td><td>avd_db</td><td></td></tr><tr><td>Table</td><td>emp</td><td></td></tr><tr><td>Created Time</td><td>Fri Nov 28 17:59:50 UTC 2025</td><td></td></tr><tr><td>Last Access</td><td>UNKNOWN</td><td></td></tr><tr><td>Created By</td><td>Spark </td><td></td></tr><tr><td>Type</td><td>MANAGED</td><td></td></tr><tr><td>Location</td><td>abfss://unity-catalog-storage@dbstoragevissqnsxh7qno.dfs.core.windows.net/2337203842480748/__unitystorage/catalogs/4f23fad5-6e40-453f-b6b4-da1ac6b5ab2f/tables/b009f6a3-113d-4f7f-8ad8-215e912582c0</td><td></td></tr><tr><td>Provider</td><td>delta</td><td></td></tr><tr><td>Owner</td><td>charushilapatil1999@gmail.com</td><td></td></tr><tr><td>Is_managed_location</td><td>true</td><td></td></tr><tr><td>Predictive Optimization</td><td>ENABLE (inherited from METASTORE metastore_azure_eastus)</td><td></td></tr><tr><td>Table Properties</td><td>[delta.enableDeletionVectors=true,delta.feature.appendOnly=supported,delta.feature.deletionVectors=supported,delta.feature.invariants=supported,delta.minReaderVersion=3,delta.minWriterVersion=7,delta.parquet.compression.codec=zstd]</td><td></td></tr></tbody></table></div>

# %% [markdown]
# # We can also Create local or global temp _view_

# %%
# ----------------------------------------------
# Create a TEMPORARY VIEW (Session Scoped)
# ----------------------------------------------
# This temporary view is available ONLY inside the current notebook/session.
# Once the session ends (cluster restart or notebook detach), the view is removed.
df.createOrReplaceTempView("course_view")

# Querying the temporary view using Spark SQL
spark.sql("SELECT * FROM course_view").show()


# ----------------------------------------------
# Create a GLOBAL TEMPORARY VIEW (Cluster Scoped)
# ----------------------------------------------
# This global temp view is accessible across ALL notebooks and ALL sessions
# running on the same cluster.
#
# It is stored under a special system database called 'global_temp'.
# You must always reference it as: global_temp.<view_name>
df.createOrReplaceGlobalTempView("course_view1")

# Querying the global temporary view using the fully qualified name
spark.sql("SELECT * FROM global_temp.course_view1").show()
# Out:
# +--------+-----+
# |language|count|
# +--------+-----+
# |  python|  100|
# |    java|  200|
# |   scala|  300|
# +--------+-----+
#
# +--------+-----+
# |language|count|
# +--------+-----+
# |  python|  100|
# |    java|  200|
# |   scala|  300|
# +--------+-----+

# %% [markdown]
# ## Table To Dataframe

# %%
# from course table we are creating dataframe

df1 = spark.table("avd_db.course")

df1.show()
# Out:
# +--------+-----+
# |language|count|
# +--------+-----+
# |  python|  100|
# |    java|  200|
# |   scala|  300|
# +--------+-----+

# %%
# %sql
-- ---------------------------------------------------------------
-- Reading a file DIRECTLY from a Volume (No table creation needed)
-- ---------------------------------------------------------------
-- In Databricks, Volumes allow you to query files directly using SQL.
-- You do NOT need to create a table or load data separately.
-- You can simply point to the file path and run SELECT on it.

-- The syntax:
-- SELECT * FROM `file_format`.`full_file_path`

-- Here, the file is a CSV, so we use: `csv`.`<path>`
-- if we have json then instead of csv we use json


SELECT * FROM `csv`.`/Volumes/avd_workspace1/avd_db/raw_data/employees.csv`;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>_c0</th><th>_c1</th><th>_c2</th><th>_c3</th><th>_c4</th><th>_c5</th></tr></thead><tbody><tr><td>id</td><td>name</td><td>salary</td><td>address</td><td>department</td><td>joined_date</td></tr><tr><td>1</td><td>Rahul</td><td>50000</td><td>Mumbai</td><td>Sales</td><td>2021-04-10</td></tr><tr><td>2</td><td>Neha</td><td>45k</td><td>Pune</td><td>HR</td><td>2020-08-15</td></tr><tr><td>3</td><td>Amit</td><td>60000</td><td>Delhi</td><td>IT</td><td>2022-01-19</td></tr><tr><td>4</td><td>John</td><td>55k</td><td>Bangalore</td><td>Marketing</td><td>2021-12-01</td></tr><tr><td>5</td><td>Meera</td><td>70000</td><td>Hyderabad</td><td>Finance</td><td>2023-03-25</td></tr><tr><td>6</td><td>Vikas</td><td>abc</td><td>Chennai</td><td>Sales</td><td>2022-07-05</td></tr><tr><td>7</td><td>Pooja</td><td>50000</td><td>InvalidAddressOnly</td><td>HR</td><td>2021-09-14</td></tr><tr><td>8</td><td>Sachin</td><td>null</td><td>Mumbai</td><td>IT</td><td>2020-02-20</td></tr><tr><td>9</td><td>InvalidRowOnly</td><td>null</td><td>null</td><td>null</td><td>null</td></tr><tr><td>10</td><td>Suresh</td><td>65k</td><td>Kolkata</td><td>Operations</td><td>2021-06-30</td></tr></tbody></table></div>
